# %%
# Import all dependencies up front this time.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

import requests
from config import weather_api_key

from datetime import datetime
import time

# %%
# Reconfigure 6.1.4 - Create a set of random latitude and longitude combinations-
# Increase to 2000.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# 6.1.4 - Make a coordinates list
coordinates = list(lat_lngs)

# %%
# Reconfigure 6.1.5 - Create a list for holding the cities.
cities =[]

# Identify the nearest city for each latitude and longitude combo.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Begin reconfiguration of 6.2.6 -

#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------------

# %%
# Put 6.2.3 here - Define url... got rid of url error by trial and error of breaking up the input boxes and putting it somewhere in the middle.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Reconfigure 6.2.6 - Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Reconfigure 6.2.6 - Run an API request for each of the cities.

    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | kiomboi
# Processing Record 3 of Set 1 | prince rupert
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | alassio
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | houma
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | praxedis guerrero
# Processing Record 15 of Set 1 | humaita
# Processing Record 16 of Set 1 | nanortalik
# Processing Record 17 of Set 1 | gerash
# Processing Record 18 of Set 1 | alofi
# Processing Record 19 of Set 1 | campos do jordao
# Processing Record 20 of Set 1 | nagato
# Processing Record 21 of Set 1 | leningradskiy
# Processing Record 22 of Set 1 | lagoa
# ...

# %%
# Printing length to later check CSV file...
len(city_data)
# Out:
# 669

# %%
# 6.2.7 - Convert the array of dictionaries to a Pandas DataFrame.
city_weather_data_df = pd.DataFrame(city_data)
city_weather_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Butaritari      KI   3.0707  172.7902     81.77        78          92
# 1        Kiomboi      TZ  -4.2667   34.3667     60.80        59          26
# 2  Prince Rupert      CA  54.3161 -130.3201     55.09        88         100
# 3   Punta Arenas      CL -53.1500  -70.9167     33.91        93         100
# 4        Ushuaia      AR -54.8000  -68.3000     38.86        81          75
# 5        Alassio      IT  44.0039    8.1671     78.06        75           2
# 6         Albany      US  42.6001  -73.9662     86.58        48          19
# 7          Houma      US  29.5958  -90.7195     77.00        88           0
# 8   Kruisfontein      ZA -34.0033   24.7314     51.26        75           0
# 9         Barrow      US  71.2906 -156.7887     39.22        87         100
#
#    Wind Speed Current Description
# 0       18.81     overcast clouds
# 1       15.17    scattered clouds
# ...

# %%
# 6.2.7 - Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the city_weather_data into a CSV.
city_weather_data_df.to_csv(output_data_file, index_label="City_ID")
